# %%
# %run ../init_framework.py

# %%
# READ: Auto Loader
df_raw = read_autoloader(spark, SRC_DEFAULTERS, defaulters_schema)

# TRANSFORM: Add Standardized Bronze Audit Metadata
df_final = add_bronze_metadata(df_raw)

# WRITE: Delta Writer
query = write_append_stream(df_final, DEFAULTERS_BRONZE, BRONZE_CHECKPOINT_DEFAULTERS)

query.awaitTermination()

# %%
# %sql
select count(1) from lending_risk.bronze.defaulters;

# %%
# %sql
select * from lending_risk.bronze.defaulters
limit 5; 
-- 753568

# %%
# dbutils.fs.rm("/Volumes/lending_risk/bronze/vol_bronze/_checkpoint/bronze_defaulters", True)
