# %%
# %run ../../config/path.py

# %%
# %run ../../config/schemas/bronze/bronze_schemas.py

# %%
print(f"Source: {SRC_CUSTOMERS}")

# 3. The Source: Standard Batch Read (NO STREAM)
df_test = (
    spark.read.format("csv")
    .option("header", "true")
    .schema(customer_schema)
    .load(SRC_CUSTOMERS)
)

# 4. The Output: Interactive Display
display(df_test)
